# %% [markdown]
# **Required Libraries:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Enable visual style
sns.set(style="whitegrid")

# %% [markdown]
# **Load the Dataset**

# %%
# Load the CSV file
df = pd.read_csv('/content/Salary Data.csv', na_values=["NA", "N/A", "", "null", "NaN", "?"])

# Show the first few rows
print("🔹 First 5 rows of the dataset:")
print(df.head())
# Out:
# 🔹 First 5 rows of the dataset:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %% [markdown]
# **Data Cleaning**

# %%
# Check for missing values
print("\n🔹 Missing values in each column:")
print(df.isnull().sum())

# Drop rows with missing values (optional — or you can fill them)
df.dropna(inplace=True)

# Check for duplicates
print("\n🔹 Number of duplicate rows:", df.duplicated().sum())

# Remove duplicates if any
df.drop_duplicates(inplace=True)

# Standardize categorical columns (optional cleaning)
df['Gender'] = df['Gender'].str.strip().str.capitalize()
df['Education Level'] = df['Education Level'].str.strip().str.title()
df['Job Title'] = df['Job Title'].str.strip().str.title()
# Out:
# 🔹 Missing values in each column:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64
#
# 🔹 Number of duplicate rows: 49

# %% [markdown]
# **Descriptive Statistics**

# %%
print("\n🔹 Descriptive statistics for numerical columns:")
print(df.describe())

print("\n🔹 Value counts for categorical columns:")
print("\nGender:\n", df['Gender'].value_counts())
print("\nEducation:\n", df['Education Level'].value_counts())
print("\nJob Title:\n", df['Job Title'].value_counts())
# Out:
# 🔹 Descriptive statistics for numerical columns:
#               Age  Years of Experience         Salary
# count  324.000000           324.000000     324.000000
# mean    37.382716            10.058642   99985.648148
# std      7.185844             6.650470   48652.271440
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.500000             9.000000   95000.000000
# 75%     44.000000            16.000000  140000.000000
# max     53.000000            25.000000  250000.000000
#
# 🔹 Value counts for categorical columns:
#
# Gender:
#  Gender
# Male      170
# Female    154
# Name: count, dtype: int64
#
# Education:
#  Education Level
# Bachelor'S    191
# Master'S       91
# Phd            42
# Name: count, dtype: int64
#
# Job Title:
#  Job Title
# Director Of Operations            9
# Director Of Marketing             8
# Senior Marketing Manager          8
# Senior Project Manager            7
# ...

# %% [markdown]
# **Grouped Analysis**

# %%
# Average salary by gender
print("\n🔹 Average salary by Gender:")
print(df.groupby('Gender')['Salary'].mean())

# Average salary by Education
print("\n🔹 Average salary by Education:")
print(df.groupby('Education Level')['Salary'].mean())

# Average salary by Job title
print("\n🔹 Average salary by Job Title:")
print(df.groupby('Job Title')['Salary'].mean())
# Out:
# 🔹 Average salary by Gender:
# Gender
# Female     96136.363636
# Male      103472.647059
# Name: Salary, dtype: float64
#
# 🔹 Average salary by Education:
# Education Level
# Bachelor'S     73902.356021
# Master'S      127912.087912
# Phd           158095.238095
# Name: Salary, dtype: float64
#
# 🔹 Average salary by Job Title:
# Job Title
# Account Manager                  75000.0
# Accountant                       55000.0
# Administrative Assistant         50000.0
# Business Analyst                 77500.0
# Business Development Manager     90000.0
#                                   ...
# Ux Designer                      80000.0
# Ux Researcher                    65000.0
# Vp Of Finance                   200000.0
# Vp Of Operations                190000.0
# Web Developer                    65000.0
# Name: Salary, Length: 174, dtype: float64

# %% [markdown]
# **Visualizations**

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Salary'], bins=20, color='teal', edgecolor='black')
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# **Gender Distribution**

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Education Levels**

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='Education', palette='muted')
plt.title("Education Level Distribution")
plt.xlabel("Education")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-19-1009242249.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Education', palette='muted')

# %% [markdown]
# **Bar Plot: Salary vs Gender**

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(data=df, x='Gender', y='Salary', palette='Set2')
plt.title("Salary Distribution by Gender")
plt.show()
# Out:
# /tmp/ipython-input-20-290141234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Gender', y='Salary', palette='Set2')

# %% [markdown]
# **Bar Plot: Salary vs Education**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Education', y='Salary', palette='Set3')
plt.title("Salary Distribution by Education")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-21-1516388835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Education', y='Salary', palette='Set3')

# %% [markdown]
# **Scatter Plot: Salary vs Years of Experience**

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='Years of Experience', y='Salary', hue='Gender', palette='Set1')
plt.title("Salary vs. Years of Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# **Scatter Plot: Salary vs Age**

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='Age', y='Salary', hue='Education', palette='Set1')
plt.title("Salary vs. Age")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend(title='Education', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# **Correlation Heatmap (for numerical columns)**

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[['Age', 'Years of Experience', 'Salary']].corr(), annot=True, cmap='Blues')
plt.title("Correlation Heatmap")
plt.show()
